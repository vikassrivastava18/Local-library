# %%
import json

# Load the JSON file with UTF-8 encoding
with open('books_data/fiction.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Print or use the data
print(len(data['items']))
# Out:
# 20

# %%
import os
import sys

# Adjust this to your project root (where manage.py lives)
PROJECT_ROOT = r"c:\Users\vikas\Documents\Local-library\backend\library"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# Point to your Django settings module (package name 'library' -> settings at library/settings.py)
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "library.settings")

import django
django.setup()

# Now safe to import Django models
from catalog.models import Book

# %%
from asgiref.sync import sync_to_async

# in a notebook cell (async context allowed)
books = await sync_to_async(list)(Book.objects.all())
books
# Out:
# [<Book: Gospel Of Sriramakrishna>]
